# %% [markdown]
# Hardware: It is physical, tangible parts of a computer or device that you can touch.
#
# Example: Keyboard (or CPU, mouse, smartphone screen)
# Software: It is the set of programs/instructions that run on hardware to make it do tasks.
#
# Example: Windows operating system (or Google Chrome, WhatsApp)
